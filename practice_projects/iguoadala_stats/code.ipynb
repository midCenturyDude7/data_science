# %% [markdown]
# <h1>Practice Notebook: Andre Iguoadala's Career Stats</h1>

# %% [markdown]
# Task: Import Andre Iguoadala's career stats as a .csv file from Basketball Reference.com and display as table using Python and Pandas

# %% [markdown]
# Import packages

# %%
import csv
import pandas as pd
import numpy as np

# %% [markdown]
# Read the file - iguoadala.csv - and covert to a pandas dataframe

# %%
df = pd.read_csv('iguoadala.csv')

# %%
df_iguoadala = pd.DataFrame(df)

# %% [markdown]
# Display the dataframe

# %%
df_iguoadala
# Out:
#        Season   Age   Tm   Lg  Pos       G     GS    MP   FG   FGA    FG%   3P  3PA    3P%   2P   2PA    2P%   eFG%   FT  FTA    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0     2004-05  21.0  PHI  NBA   SG    82.0   82.0  32.8  3.3   6.7  0.493  0.6  1.7  0.331  2.7   4.9  0.550  0.536  1.9  2.6  0.743  1.1  4.6  5.7  3.0  1.7  0.6  1.7  2.5   9.0
# 1     2005-06  22.0  PHI  NBA   SF    82.0   82.0  37.6  4.2   8.4  0.500  0.7  1.9  0.354  3.5   6.5  0.543  0.541  3.2  4.3  0.754  1.4  4.4  5.9  3.1  1.6  0.3  1.9  2.4  12.3
# 2     2006-07  23.0  PHI  NBA   SG    76.0   76.0  40.3  5.8  13.0  0.447  0.6  2.0  0.310  5.2  11.0  0.472  0.471  5.9  7.3  0.820  1.0  4.7  5.7  5.7  2.0  0.4  3.4  2.6  18.2
# 3     2007-08  24.0  PHI  NBA   SF    82.0   82.0  39.5  7.1  15.6  0.456  1.2  3.7  0.329  5.9  11.8  0.496  0.495  4.5  6.2  0.721  1.0  4.4  5.4  4.8  2.1  0.6  2.6  2.3  19.9
# ...
